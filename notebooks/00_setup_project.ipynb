# %%
#Check Spark session and environment
print("Spark version: ", spark.version)

# Simple test to verify compute is working
data = [("OK", 1)]
df = spark.createDataFrame(data, ["status", "value"])
df.show()
# DBTITLE 1]

# %%
# %sql
-- Create catalog for the project
CREATE CATALOG IF NOT EXISTS taxi_catalog;

-- Create schema insite the catalog
CREATE SCHEMA IF NOT EXISTS taxi_catalog.bronze;

-- Confirm catalog exists
SHOW CATALOGS;

# %%
# %sql
--Create a volume for raw/bronze/silver/gold data
CREATE VOLUME IF NOT EXISTS taxi_catalog.bronze.taxi_volume;

# %%
# %sql
SHOW VOLUMES IN taxi_catalog.bronze;

# %%
# Base Path fo the UC-managed volume
base_path = "/Volumes/taxi_catalog/bronze/taxi_volume"

# Create medallion directoris
dbutils.fs.mkdirs(f"{base_path}/bronze")
dbutils.fs.mkdirs(f"{base_path}/silver")
dbutils.fs.mkdirs(f"{base_path}/gold")

# List the structure to confirm
display(dbutils.fs.ls(base_path))
